# %% [markdown]
# <a href="https://colab.research.google.com/github/adriangarciaabenza/geoPy/blob/main/precipitacion_diaria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cálculo de la Precipitación Diaria en la Región de Murcia

# %%
! git clone https://github.com/adriangarciaabenza/geoPy
# Out:
# Cloning into 'geoPy'...
# remote: Enumerating objects: 243, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 243 (delta 5), reused 34 (delta 5), pack-reused 208
# Receiving objects: 100% (243/243), 234.42 MiB | 12.31 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# Updating files: 100% (308/308), done.

# %%
# !pip install cartopy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 45.5 MB/s eta 0:00:00
# ...

# %%
from geoPy.tools.BNDCtools import *

# %%
# Example Usage:
csv_file_path = "geoPy/AppInput/Pcp072023.csv"
coast_shapefile ='geoPy/tools/assets/ne_10m_coastline/ne_10m_coastline.shp'
bndc_dataset = BNDCdataSet.from_csv(csv_file_path)

# Plotting data points colored by 'type'
#bndc_dataset.plot_data_points(color_by='ALTITUD', cmap='viridis', markersize=10, figsize=(10, 8))

# Show the plot
#plt.show()

bndc_dataset.compute_distance_to_sea(coast_shapefile=coast_shapefile)
bndc_dataset.plot_data_points(color_by='distance_to_sea', cmap='viridis', markersize=10, figsize=(10, 8))
plt.show()
# Out:
#                                             geometry
# 0  POLYGON ((2779506.802 -8800491.662, 2774893.48...
#     INDICATIVO   AÑO  MES  ALTITUD     C_X      C_Y  P1  P2  P3  P4  ...  P24  \
# 0         5057  2023    7     1271  562870  4209161   0  82   0   0  ...    0
# 1        5060X  2023    7     1190  567903  4190655   0   0   0   0  ...    0
# 2        6367B  2023    7      300  593512  4138723   0   0   0   0  ...    0
# 3        6371I  2023    7      310  613139  4151101   0   0   0   0  ...    0
# 4        7002Y  2023    7       26  625041  4142095   0   0   0   0  ...    0
# ..         ...   ...  ...      ...     ...      ...  ..  ..  ..  ..  ...  ...
# 166       8059  2023    7      767  715503  4286186   0   0   0   0  ...    0
# 167      8059D  2023    7     1028  714101  4282570   0   0   0   0  ...    0
# 168      8198Y  2023    7      710  668083  4301976   0   0   0   0  ...    0
# 169       8282  2023    7      643  706883  4293208   0   0   0   0  ...    0
# ...
